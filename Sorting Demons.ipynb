# %%
import random 

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from initialize_world import create_sorting_world
from utils import _summarize, take_first
from elements import Dreg, Res, Sorter, Emitter, Data
from Simulator import simulator

# %%
loop = {1: Dreg, 
        2: Res, 
        3: Sorter, 
        4: Data, 
        5: Emitter}

n_rows = 30
n_cols = 60
epochs = 200000
ENV = create_sorting_world(n_rows=n_rows, n_cols=n_cols, n_dregs=10, n_sorters=5, n_emitters=10)
CANVASS = np.zeros((n_rows, n_cols))

# %%
simulator(ENV, CANVASS, epochs, loop)

# %%
# we want data elements on the left side of the board

keep = []
for k in ENV.keys():
    if isinstance(k, tuple):
        if k[1] < 20 and ENV[k][0] == 4:
            keep.append(k)
# keep

# shuld be descending order

sorted_list = sorted(keep, key=take_first)

ans = []
for i in sorted_list:
    ans.append(ENV[i][1])
    
plt.plot(ans)

# %%
# https://ezgif.com/
